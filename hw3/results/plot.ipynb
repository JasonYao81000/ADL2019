# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
N = 1000

# %%
pg_episode_rewards = np.load('pg_episode_rewards.npy')
pg_recent_avg_rewards = []
for i in range(pg_episode_rewards.shape[0]):
    recent_rewards = pg_episode_rewards[max(0, i - N):i + 1]
    pg_recent_avg_rewards.append(sum(recent_rewards) / len(recent_rewards))

# %%
plt.clf()
plt.figure(figsize=(16, 5))
plt.title('Reward v.s. Episode')
plt.ylabel('Average reward in last %d episodes' % (N))
plt.xlabel('# of episodes')
plt.plot(pg_recent_avg_rewards)
plt.savefig('reward_episode_pg.png')
plt.show()

# %%
pg_ppo_episode_rewards = np.load('pg-ppo_episode_rewards.npy')
pg_ppo_recent_avg_rewards = []
for i in range(pg_ppo_episode_rewards.shape[0]):
    recent_rewards = pg_ppo_episode_rewards[max(0, i - N):i + 1]
    pg_ppo_recent_avg_rewards.append(sum(recent_rewards) / len(recent_rewards))

# %%
plt.clf()
plt.figure(figsize=(16, 5))
plt.title('Reward v.s. Episode')
plt.ylabel('Average reward in last %d episodes' % (N))
plt.xlabel('# of episodes')
plt.plot(pg_ppo_recent_avg_rewards)
plt.savefig('reward_episode_pg-ppo.png')
plt.show()

# %%
plt.clf()
plt.figure(figsize=(16, 5))
plt.plot(pg_recent_avg_rewards, label='Policy Gradient')
plt.plot(pg_ppo_recent_avg_rewards, label='Policy Gradient w/ PPO')
plt.legend(loc='lower right')
plt.title('Reward v.s. Episode')
plt.ylabel('Average reward in last %d episodes' % (N))
plt.xlabel('# of episodes')
plt.savefig('reward_episode_pgs.png')
plt.show()

# %%
N = 1000

# %%
double_duel_dqn_episode_rewards = np.load('double_duel_dqn_episode_rewards.npy')
double_duel_dqn_recent_avg_rewards = []
for i in range(double_duel_dqn_episode_rewards.shape[0]):
    recent_rewards = double_duel_dqn_episode_rewards[max(0, i - N):i + 1]
    double_duel_dqn_recent_avg_rewards.append(sum(recent_rewards) / len(recent_rewards))

# %%
double_dqn_episode_rewards = np.load('double_dqn_episode_rewards.npy')
double_dqn_recent_avg_rewards = []
for i in range(double_dqn_episode_rewards.shape[0]):
    recent_rewards = double_dqn_episode_rewards[max(0, i - N):i + 1]
    double_dqn_recent_avg_rewards.append(sum(recent_rewards) / len(recent_rewards))

# %%
duel_dqn_episode_rewards = np.load('duel_dqn_episode_rewards.npy')
duel_dqn_recent_avg_rewards = []
for i in range(duel_dqn_episode_rewards.shape[0]):
    recent_rewards = duel_dqn_episode_rewards[max(0, i - N):i + 1]
    duel_dqn_recent_avg_rewards.append(sum(recent_rewards) / len(recent_rewards))

# %%
dqn_episode_rewards = np.load('dqn_episode_rewards.npy')
dqn_recent_avg_rewards = []
for i in range(dqn_episode_rewards.shape[0]):
    recent_rewards = dqn_episode_rewards[max(0, i - N):i + 1]
    dqn_recent_avg_rewards.append(sum(recent_rewards) / len(recent_rewards))

# %%
plt.clf()
plt.figure(figsize=(16, 5))
plt.title('Reward v.s. Episode')
plt.ylabel('Average reward in last %d episodes' % (N))
plt.xlabel('# of episodes')
plt.plot(double_duel_dqn_recent_avg_rewards)
plt.savefig('reward_episode_double_duel.png')
plt.show()

# %%
plt.clf()
plt.figure(figsize=(16, 5))
plt.title('Reward v.s. Episode')
plt.ylabel('Average reward in last %d episodes' % (N))
plt.xlabel('# of episodes')
plt.plot(double_dqn_recent_avg_rewards)
plt.savefig('reward_episode_double.png')
plt.show()

# %%
plt.clf()
plt.figure(figsize=(16, 5))
plt.title('Reward v.s. Episode')
plt.ylabel('Average reward in last %d episodes' % (N))
plt.xlabel('# of episodes')
plt.plot(duel_dqn_recent_avg_rewards)
plt.savefig('reward_episode_duel.png')
plt.show()

# %%
plt.clf()
plt.figure(figsize=(16, 5))
plt.title('Reward v.s. Episode')
plt.ylabel('Average reward in last %d episodes' % (N))
plt.xlabel('# of episodes')
plt.plot(dqn_recent_avg_rewards)
plt.savefig('reward_episode_dqn.png')
plt.show()

# %%
plt.clf()
plt.figure(figsize=(16, 16))
plt.plot(double_duel_dqn_recent_avg_rewards, label='double duel')
plt.plot(double_dqn_recent_avg_rewards, label='double')
plt.plot(duel_dqn_recent_avg_rewards, label='duel')
plt.plot(dqn_recent_avg_rewards, label='dqn')
plt.legend(loc='lower right')
plt.title('Reward v.s. Episode')
plt.ylabel('Average reward in last %d episodes' % (N))
plt.xlabel('# of episodes')
plt.savefig('reward_episode_dqns.png')
plt.show()

# %%
N = 1000

# %%
a2c_world_0_avg_rewards = np.load('a2c-world-0_avg_rewards.npy') * 15.0
a2c_world_0_recent_avg_rewards = []
for i in range(a2c_world_0_avg_rewards.shape[0]):
    recent_rewards = a2c_world_0_avg_rewards[max(0, i - N):i + 1]
    a2c_world_0_recent_avg_rewards.append(sum(recent_rewards) / len(recent_rewards))

# %%
plt.clf()
plt.figure(figsize=(16, 5))
plt.title('Reward v.s. Episode')
plt.ylabel('Average reward in last %d episodes' % (N * 10))
plt.xlabel('# of episodes')
plt.plot(a2c_world_0_recent_avg_rewards)
plt.savefig('reward_episode_a2c_world_0.png')
plt.show()

# %%
a2c_world_1_avg_rewards = np.load('a2c-world-1_avg_rewards.npy') * 15.0
a2c_world_1_recent_avg_rewards = []
for i in range(a2c_world_1_avg_rewards.shape[0]):
    recent_rewards = a2c_world_1_avg_rewards[max(0, i - N):i + 1]
    a2c_world_1_recent_avg_rewards.append(sum(recent_rewards) / len(recent_rewards))

# %%
plt.clf()
plt.figure(figsize=(16, 5))
plt.title('Reward v.s. Episode')
plt.ylabel('Average reward in last %d episodes' % (N * 10))
plt.xlabel('# of episodes')
plt.plot(a2c_world_1_recent_avg_rewards)
plt.savefig('reward_episode_a2c_world_1.png')
plt.show()

# %%
plt.clf()
plt.figure(figsize=(16, 5))
plt.plot(a2c_world_0_recent_avg_rewards, label='A2C all worlds')
plt.plot(a2c_world_1_recent_avg_rewards, label='A2c world 1')
plt.legend(loc='lower right')
plt.title('Reward v.s. Episode')
plt.ylabel('Average reward in last %d episodes' % (N))
plt.xlabel('# of episodes')
plt.savefig('reward_episode_A2Cs.png')
plt.show()

# %%
plt.clf()
plt.figure(figsize=(16, 5))
plt.plot(a2c_world_0_recent_avg_rewards[::4], label='A2C all worlds, skip 4')
plt.plot(a2c_world_1_recent_avg_rewards, label='A2c world 1')
plt.legend(loc='lower right')
plt.title('Reward v.s. Episode')
plt.ylabel('Average reward in last %d episodes' % (N))
plt.xlabel('# of episodes')
plt.savefig('reward_episode_A2Cs_4.png')
plt.show()
